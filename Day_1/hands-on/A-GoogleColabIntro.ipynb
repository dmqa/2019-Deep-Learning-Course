# %% [markdown]
# # 구글 코랩 (Google Colaboratory)
# 1. 지메일(Gmail) 계정만 있다면 별도의 Python 설치가 없이 웹 브라우저만으로 클라우드 환경에서 주피터 노트북(Jupyter Notebook)을 열고 실행할 수 있음.
# 2. 데이터 분석 및 기계학습 연구에 많이 쓰이는 tensorflow, keras, matplotlib, scikit-learn, pandas, pytorch 등이 이미 설치되어 있음.
# 3. 최대 12시간 연속으로 NVIDIA ~~Tesla K80~~ Tesla T4 GPU를 무료로 사용 가능함 (약 ~~12GB~~ 15GB)

# %% [markdown]
# ## CPU 정보 확인

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# ...

# %% [markdown]
# ## 운영체제(OS) 정보 확인

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.2 LTS

# %% [markdown]
# ## 메모리(RAM) 정보 확인

# %%
# !cat /proc/meminfo | grep MemTotal*
# Out:
# MemTotal:       13335276 kB

# %% [markdown]
# ## 디스크 정보 확인

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         359G   30G  311G   9% /
# tmpfs           6.4G     0  6.4G   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# /dev/sda1       365G   40G  326G  11% /opt/bin
# tmpfs           6.4G   16K  6.4G   1% /var/colab
# shm             6.0G  4.0K  6.0G   1% /dev/shm
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# ## 그래픽카드(GPU) 정보 확인

# %%
# !nvidia-smi
# Out:
# Mon Jul 29 03:52:16 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    16W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %% [markdown]
# ## 파이썬(Python) 버전 정보 확인

# %%
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.6.8

# %% [markdown]
# ## 설치된 파이썬 패키지 보기

# %%
# Check installed python packages
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.7.1
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   3.1.0
# astor                    0.8.0
# astropy                  3.0.5
# atari-py                 0.1.15
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.8
# autograd                 1.2
# Babel                    2.7.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# blis                     0.2.4
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.189
# botocore                 1.12.189
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.1
# ...

# %% [markdown]
# ## 현재 작업 디렉토리 및 하위 파일 목록 확인

# %%
# !echo 'Current working directory:' $PWD
# !ls -al
# Out:
# Current working directory: /content
# total 16
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 .
# drwxr-xr-x 1 root root 4096 Jul 29 03:45 ..
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 .config
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 sample_data

# %% [markdown]
# ## 클라우드 환경에 구글 드라이브 마운트하기
# - 구글 드라이브에 위치한 파일(데이터, 스크립트 등)에 접근하기 위한 작업
# - 경로는 '/content/gdrive/My Drive/'에 마운트됨

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
# !ls -al '/content/gdrive/My Drive/'
# Out:
# ls: cannot access '/content/gdrive/My Drive/': No such file or directory

# %%
import os

ROOT_DIR = '/content/gdrive/My Drive/'
os.chdir(ROOT_DIR)

# !echo 'Current working directory:' $PWD
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-5e20957ffe29> in <module>()
#       2
#       3 ROOT_DIR = '/content/gdrive/My Drive/'
# ----> 4 os.chdir(ROOT_DIR)
#       5
#       6 get_ipython().system("echo 'Current working directory:' $PWD")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/'
